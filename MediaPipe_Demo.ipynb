# %% [markdown]
# This demo uses media pipe to idenify human faces and features on those faces. It is able to identify the images of faces correctly, and correctly ignores the images of cat faces.

# %%
# !pip install mediapipe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 32.2 MB/s eta 0:00:00
# ...

# %%
import mediapipe as mp
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

# Initialize face detection model
face_detection = mp_face_detection.FaceDetection(min_detection_confidence=0.5)

# %%
def process_image(image_path):
    # Read image
    image = cv2.imread(image_path)
    # Convert the color space from BGR to RGB
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Process the image and detect faces
    results = face_detection.process(image)

    # Convert back to BGR for displaying
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    if results.detections:
        for detection in results.detections:
            mp_drawing.draw_detection(image, detection)

    # Display the image
    cv2_imshow(image)

# %%
# !wget [IMAGE_URL] -O test.jpg
process_image('face1.jpg')
# Out:
# http://[IMAGE_URL]: Invalid IPv6 numeric address.
# <PIL.Image.Image image mode=RGB size=197x148>

# %%
# !wget [IMAGE_URL] -O test.jpg
process_image('face2.jpg')
# Out:
# http://[IMAGE_URL]: Invalid IPv6 numeric address.
# <PIL.Image.Image image mode=RGB size=151x148>

# %%
# !wget [IMAGE_URL] -O test.jpg
process_image('cat1.jpg')
# Out:
# http://[IMAGE_URL]: Invalid IPv6 numeric address.
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# !wget [IMAGE_URL] -O test.jpg
process_image('cat2.jpg')
# Out:
# http://[IMAGE_URL]: Invalid IPv6 numeric address.
# <PIL.Image.Image image mode=RGB size=512x512>
